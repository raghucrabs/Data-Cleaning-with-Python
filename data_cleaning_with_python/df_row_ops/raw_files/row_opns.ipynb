# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read the data

# %%
df = pd.read_csv("raw_data/nls97.csv")

# %% [markdown]
# ## Set the "personid" column as the index

# %%
df.set_index("personid", inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8984 entries, 100061 to 999963
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 8984 non-null   object
#  1   birthmonth             8984 non-null   int64
#  2   birthyear              8984 non-null   int64
#  3   highestgradecompleted  6663 non-null   float64
#  4   maritalstatus          6672 non-null   object
#  5   childathome            4791 non-null   float64
#  6   childnotathome         4791 non-null   float64
#  7   wageincome             5091 non-null   float64
#  8   weeklyhrscomputer      5792 non-null   object
#  9   weeklyhrstv            6711 non-null   object
#  10  nightlyhrssleep        6706 non-null   float64
#  11  satverbal              1406 non-null   float64
#  12  satmath                1407 non-null   float64
#  13  gpaoverall             6004 non-null   float64
# ...

# %%
df.head(6)
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted  maritalstatus  \
# personid
# 100061    Female           5       1980                   13.0        Married
# 100139      Male           9       1983                   12.0        Married
# 100284      Male          11       1984                    7.0  Never-married
# 100292      Male           4       1982                    NaN            NaN
# 100583      Male           1       1980                   13.0        Married
# 100833      Male           1       1981                   12.0        Married
#
#           childathome  childnotathome  wageincome        weeklyhrscomputer  \
# personid
# 100061            4.0             0.0     12500.0  10 hours or more a week
# 100139            2.0             0.0    120000.0      1 to 3 hours a week
# 100284            1.0             0.0     58000.0                      NaN
# 100292            NaN             NaN         NaN                      NaN
# ...

# %% [markdown]
# ## Selecting the rows by Slicing the fifth to eighth rows

# %%
df[4:8] # Fifth row is index 4
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted  maritalstatus  \
# personid
# 100583      Male           1       1980                   13.0        Married
# 100833      Male           1       1981                   12.0        Married
# 100931    Female           8       1983                   15.0       Divorced
# 101089      Male           4       1980                   13.0  Never-married
#
#           childathome  childnotathome  wageincome        weeklyhrscomputer  \
# personid
# 100583            4.0             0.0     30000.0  Less than 1 hour a week
# 100833            2.0             0.0     39000.0      1 to 3 hours a week
# 100931            2.0             0.0     56000.0  10 hours or more a week
# 101089            NaN             NaN     36000.0      4 to 6 hours a week
#
#                          weeklyhrstv  ...         colenrfeb13  \
# personid                              ...
# 100583          3 to 10 hours a week  ...     1. Not enrolled
# ...

# %%
# Transpose of the sliced data

df[4:8].T
# Out:
# personid                        100583           100833           100931  \
# gender                            Male             Male           Female
# birthmonth                           1                1                8
# birthyear                         1980             1981             1983
# highestgradecompleted             13.0             12.0             15.0
# maritalstatus                  Married          Married         Divorced
# ...                                ...              ...              ...
# colenroct15            1. Not enrolled  1. Not enrolled  1. Not enrolled
# colenrfeb16            1. Not enrolled  1. Not enrolled  1. Not enrolled
# colenroct16            1. Not enrolled  1. Not enrolled  1. Not enrolled
# colenrfeb17            1. Not enrolled  1. Not enrolled  1. Not enrolled
# colenroct17            1. Not enrolled  1. Not enrolled  1. Not enrolled
#
# personid                        101089
# gender                            Male
# ...

# %% [markdown]
# ## Slicing with a step

# %%
df[4:14:2] # Selecting every other row starting from index 4 (row 5)
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted  maritalstatus  \
# personid
# 100583      Male           1       1980                   13.0        Married
# 100931    Female           8       1983                   15.0       Divorced
# 101122      Male           2       1981                    NaN            NaN
# 101230    Female           2       1984                   11.0  Never-married
# 101414      Male           6       1984                   12.0  Never-married
#
#           childathome  childnotathome  wageincome        weeklyhrscomputer  \
# personid
# 100583            4.0             0.0     30000.0  Less than 1 hour a week
# 100931            2.0             0.0     56000.0  10 hours or more a week
# 101122            NaN             NaN         NaN                      NaN
# 101230            2.0             0.0         NaN                      NaN
# 101414            2.0             0.0     20000.0                      NaN
#
# ...

# %% [markdown]
# ## Slicing the last three rows of the dataframe using "tail"

# %%
df.tail(3)
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted  maritalstatus  \
# personid
# 999543    Female           8       1984                   12.0       Divorced
# 999698    Female           5       1983                   12.0  Never-married
# 999963    Female           9       1982                   17.0        Married
#
#           childathome  childnotathome  wageincome    weeklyhrscomputer  \
# personid
# 999543            2.0             0.0         NaN                  NaN
# 999698            5.0             0.0         NaN  4 to 6 hours a week
# 999963            2.0             0.0     50000.0  4 to 6 hours a week
#
#                         weeklyhrstv  ...      colenrfeb13      colenroct13  \
# personid                             ...
# 999543         3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
# 999698    More than 40 hours a week  ...  1. Not enrolled  1. Not enrolled
# 999963         3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
#
# ...

# %% [markdown]
# ## Slicing the last three rows of the dataframe using "negative index"

# %%
df[-3:]
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted  maritalstatus  \
# personid
# 999543    Female           8       1984                   12.0       Divorced
# 999698    Female           5       1983                   12.0  Never-married
# 999963    Female           9       1982                   17.0        Married
#
#           childathome  childnotathome  wageincome    weeklyhrscomputer  \
# personid
# 999543            2.0             0.0         NaN                  NaN
# 999698            5.0             0.0         NaN  4 to 6 hours a week
# 999963            2.0             0.0     50000.0  4 to 6 hours a week
#
#                         weeklyhrstv  ...      colenrfeb13      colenroct13  \
# personid                             ...
# 999543         3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
# 999698    More than 40 hours a week  ...  1. Not enrolled  1. Not enrolled
# 999963         3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
#
# ...

# %% [markdown]
# ## Using "loc" to select few rows by index label

# %%
df.loc[195884:195970] #passing a range of labels
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted  maritalstatus  \
# personid
# 195884      Male          12       1981                    NaN            NaN
# 195891      Male           9       1980                   12.0  Never-married
# 195970    Female           3       1982                   17.0  Never-married
#
#           childathome  childnotathome  wageincome        weeklyhrscomputer  \
# personid
# 195884            NaN             NaN         NaN                      NaN
# 195891            NaN             NaN     14000.0  Less than 1 hour a week
# 195970            2.0             0.0     52000.0  10 hours or more a week
#
#                    weeklyhrstv  ...      colenrfeb13      colenroct13  \
# personid                        ...
# 195884                     NaN  ...              NaN              NaN
# 195891    3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
# 195970    3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
#
# ...

# %%
df.loc[[195884,195891,195970]] # Passing a list of index labels
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted  maritalstatus  \
# personid
# 195884      Male          12       1981                    NaN            NaN
# 195891      Male           9       1980                   12.0  Never-married
# 195970    Female           3       1982                   17.0  Never-married
#
#           childathome  childnotathome  wageincome        weeklyhrscomputer  \
# personid
# 195884            NaN             NaN         NaN                      NaN
# 195891            NaN             NaN     14000.0  Less than 1 hour a week
# 195970            2.0             0.0     52000.0  10 hours or more a week
#
#                    weeklyhrstv  ...      colenrfeb13      colenroct13  \
# personid                        ...
# 195884                     NaN  ...              NaN              NaN
# 195891    3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
# 195970    3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
#
# ...

# %% [markdown]
# ## Selecting rows using "iloc"

# %%
df.iloc[[0,4,5]] # Give a list of row positions- not index labels
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted maritalstatus  \
# personid
# 100061    Female           5       1980                   13.0       Married
# 100583      Male           1       1980                   13.0       Married
# 100833      Male           1       1981                   12.0       Married
#
#           childathome  childnotathome  wageincome        weeklyhrscomputer  \
# personid
# 100061            4.0             0.0     12500.0  10 hours or more a week
# 100583            4.0             0.0     30000.0  Less than 1 hour a week
# 100833            2.0             0.0     39000.0      1 to 3 hours a week
#
#                     weeklyhrstv  ...      colenrfeb13      colenroct13  \
# personid                         ...
# 100061    11 to 20 hours a week  ...  1. Not enrolled  1. Not enrolled
# 100583     3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
# 100833     3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
#
# ...

# %%
df.iloc[0:3]
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted  maritalstatus  \
# personid
# 100061    Female           5       1980                   13.0        Married
# 100139      Male           9       1983                   12.0        Married
# 100284      Male          11       1984                    7.0  Never-married
#
#           childathome  childnotathome  wageincome        weeklyhrscomputer  \
# personid
# 100061            4.0             0.0     12500.0  10 hours or more a week
# 100139            2.0             0.0    120000.0      1 to 3 hours a week
# 100284            1.0             0.0     58000.0                      NaN
#
#                     weeklyhrstv  ...      colenrfeb13      colenroct13  \
# personid                         ...
# 100061    11 to 20 hours a week  ...  1. Not enrolled  1. Not enrolled
# 100139     3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
# 100284    11 to 20 hours a week  ...  1. Not enrolled  1. Not enrolled
#
# ...

# %% [markdown]
# ## Select multiple rows using a condition

# %%
df.columns
# Out:
# Index(['gender', 'birthmonth', 'birthyear', 'highestgradecompleted',
#        'maritalstatus', 'childathome', 'childnotathome', 'wageincome',
#        'weeklyhrscomputer', 'weeklyhrstv', 'nightlyhrssleep', 'satverbal',
#        'satmath', 'gpaoverall', 'gpaenglish', 'gpamath', 'gpascience',
#        'highestdegree', 'govprovidejobs', 'govpricecontrols', 'govhealthcare',
#        'govelderliving', 'govindhelp', 'govunemp', 'govincomediff',
#        'govcollegefinance', 'govdecenthousing', 'govprotectenvironment',
#        'weeksworked00', 'weeksworked01', 'weeksworked02', 'weeksworked03',
#        'weeksworked04', 'weeksworked05', 'weeksworked06', 'weeksworked07',
#        'weeksworked08', 'weeksworked09', 'weeksworked10', 'weeksworked11',
#        'weeksworked12', 'weeksworked13', 'weeksworked14', 'weeksworked15',
#        'weeksworked16', 'weeksworked17', 'colenrfeb97', 'colenroct97',
#        'colenrfeb98', 'colenroct98', 'colenrfeb99', 'colenroct99',
# ...

# %%
df.nightlyhrssleep.describe()
# Out:
# count    6706.000000
# mean        6.637340
# std         1.364404
# min         0.000000
# 25%         6.000000
# 50%         7.000000
# 75%         8.000000
# max        20.000000
# Name: nightlyhrssleep, dtype: float64

# %%
df.nightlyhrssleep.quantile(0.25)
# Out:
# 6.0

# %%
df.nightlyhrssleep.quantile(0.05)
# Out:
# 4.0

# %% [raw]
# Out of 6706 people responded to this question,
# 5 % of people responded that they have 4 hrs or less than 4 hrs of sleep

# %% [markdown]
# ## Selecting the rows who have 4 hrs or less sleep

# %%
low_sleep_people = df.loc[df.nightlyhrssleep<=4]

# %%
low_sleep_people.shape
# Out:
# (364, 88)

# %% [markdown]
# ## Select rows based on multiple conditions

# %%
low_sleep_people.head(2)
# Out:
#          gender  birthmonth  birthyear  highestgradecompleted  maritalstatus  \
# personid
# 101414     Male           6       1984                   12.0  Never-married
# 102454     Male           4       1982                   16.0        Married
#
#           childathome  childnotathome  wageincome    weeklyhrscomputer  \
# personid
# 101414            2.0             0.0     20000.0                  NaN
# 102454            NaN             NaN         NaN  1 to 3 hours a week
#
#                    weeklyhrstv  ...      colenrfeb13      colenroct13  \
# personid                        ...
# 101414    3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
# 102454    3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
#
#               colenrfeb14      colenroct14      colenrfeb15  \
# personid
# 101414    1. Not enrolled  1. Not enrolled  1. Not enrolled
# 102454    1. Not enrolled  1. Not enrolled  1. Not enrolled
#
# ...

# %%
low_sleep_people.childathome.describe() 

# to get the distribution of number of children" among low_sleep_people
# Out:
# count    293.000000
# mean       1.788396
# std        1.400685
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        9.000000
# Name: childathome, dtype: float64

# %% [markdown]
# About a quarter have 3 or more children

# %%
low_sleep_3_plus_children = df.loc[(df.nightlyhrssleep <=4) & (df.childathome >=3)]

# %%
low_sleep_3_plus_children.shape
# Out:
# (82, 88)

# %%
low_sleep_3_plus_children.head(3)
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted  maritalstatus  \
# personid
# 119754    Female           6       1980                   11.0       Divorced
# 141531    Female          11       1980                   13.0        Married
# 152706      Male           7       1984                   12.0  Never-married
#
#           childathome  childnotathome  wageincome    weeklyhrscomputer  \
# personid
# 119754            4.0             2.0         NaN                  NaN
# 141531            5.0             0.0      9000.0                  NaN
# 152706            4.0             0.0     45000.0  4 to 6 hours a week
#
#                          weeklyhrstv  ...      colenrfeb13        colenroct13  \
# personid                              ...
# 119754         11 to 20 hours a week  ...  1. Not enrolled    1. Not enrolled
# 141531    Less than 2 hours per week  ...  1. Not enrolled  3. 4-year college
# ...

# %%
low_sleep_people.maritalstatus.value_counts()
# Out:
# maritalstatus
# Never-married    167
# Married          122
# Divorced          55
# Separated         13
# Name: count, dtype: int64

# %%
low_sleep_people.gender.value_counts()
# Out:
# gender
# Female    184
# Male      180
# Name: count, dtype: int64

# %% [markdown]
# ##  Selecting rows - 3 conditions

# %%
low_sleep_3_plus_children_females = df.loc[(df.nightlyhrssleep <=4) & \
                                            (df.childathome >=3) & \
                                            (df.gender == "Female")
                                           ]

# %%
low_sleep_3_plus_children_females.shape
# Out:
# (57, 88)

# %% [markdown]
# ## Selecting rows and columns using "loc"

# %%
low_sleep_3_plus_child = df.loc[
                                (df.nightlyhrssleep <=4) & \
                                (df.childathome >=3),\
                                ['nightlyhrssleep', 'childathome']
                                ]

# %%
low_sleep_3_plus_child.head(5)
# Out:
#           nightlyhrssleep  childathome
# personid
# 119754                4.0          4.0
# 141531                4.0          5.0
# 152706                4.0          4.0
# 156823                1.0          3.0
# 158355                4.0          4.0
