# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read the data

# %%
df = pd.read_csv("raw_data/nls97.csv")

# %%
df.set_index("personid", inplace = True)

# %%
df.columns
# Out:
# Index(['gender', 'birthmonth', 'birthyear', 'highestgradecompleted',
#        'maritalstatus', 'childathome', 'childnotathome', 'wageincome',
#        'weeklyhrscomputer', 'weeklyhrstv', 'nightlyhrssleep', 'satverbal',
#        'satmath', 'gpaoverall', 'gpaenglish', 'gpamath', 'gpascience',
#        'highestdegree', 'govprovidejobs', 'govpricecontrols', 'govhealthcare',
#        'govelderliving', 'govindhelp', 'govunemp', 'govincomediff',
#        'govcollegefinance', 'govdecenthousing', 'govprotectenvironment',
#        'weeksworked00', 'weeksworked01', 'weeksworked02', 'weeksworked03',
#        'weeksworked04', 'weeksworked05', 'weeksworked06', 'weeksworked07',
#        'weeksworked08', 'weeksworked09', 'weeksworked10', 'weeksworked11',
#        'weeksworked12', 'weeksworked13', 'weeksworked14', 'weeksworked15',
#        'weeksworked16', 'weeksworked17', 'colenrfeb97', 'colenroct97',
#        'colenrfeb98', 'colenroct98', 'colenrfeb99', 'colenroct99',
#        'colenrfeb00', 'colenroct00', 'colenrfeb01', 'colenroct01',
#        'colenrfeb02', 'colenroct02', 'colenrfeb03', 'colenroct03',
#        'colenrfeb04', 'colenroct04', 'colenrfeb05', 'colenroct05',
#        'colenrfeb06', 'colenroct06', 'colenrfeb07', 'colenroct07',
#        'colenrfeb08', 'colenroct08', 'colenrfeb09', 'colenroct09',
#        'colenrfeb10', 'colenroct10', 'colenrfeb11', 'colenroct11',
#        'colenrfeb12', 'colenroct12', 'colenrfeb13', 'colenroct13',
#        'colenrfeb14', 'colenroct14', 'colenrfeb15', 'colenroct15',
#        'colenrfeb16', 'colenroct16', 'colenrfeb17', 'colenroct17'],
#       dtype='object')

# %% [markdown]
# ## Look at the employment and education data

# %%
df[['wageincome', 'highestgradecompleted', 'highestdegree']].head(3)
# Out:
#           wageincome  highestgradecompleted   highestdegree
# personid
# 100061       12500.0                   13.0  2. High School
# 100139      120000.0                   12.0  2. High School
# 100284       58000.0                    7.0         0. None

# %% [markdown]
# ## Look at weeksworked between 2012 and 2017

# %%
df.loc[:,"weeksworked12":"weeksworked17"].head(3)
# Out:
#           weeksworked12  weeksworked13  weeksworked14  weeksworked15  \
# personid
# 100061             40.0           52.0           52.0           52.0
# 100139             52.0           52.0           52.0           52.0
# 100284              0.0            NaN           11.0           52.0
#
#           weeksworked16  weeksworked17
# personid
# 100061             48.0           48.0
# 100139             53.0           52.0
# 100284             47.0            0.0

# %% [markdown]
# ## Look at College enrolment between 2009 and 2014

# %%
df.loc[:,"colenroct09":"colenroct14"].head(3)
# Out:
#               colenroct09      colenrfeb10      colenroct10      colenrfeb11  \
# personid
# 100061    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100139    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100284    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
#
#                 colenroct11        colenrfeb12        colenroct12  \
# personid
# 100061    3. 4-year college  3. 4-year college  3. 4-year college
# 100139      1. Not enrolled    1. Not enrolled    1. Not enrolled
# 100284      1. Not enrolled    1. Not enrolled    1. Not enrolled
#
#               colenrfeb13      colenroct13      colenrfeb14      colenroct14
# personid
# 100061    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100139    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100284    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled

# %% [markdown]
# ## Show individuals with wage income but no weeks worked in 2016

# %%
df.loc[(df.weeksworked16 ==0) & (df.wageincome) >0, ['weeksworked16', 'wageincome']]
# Out:
#           weeksworked16  wageincome
# personid
# 102625              0.0      1200.0
# 109403              0.0      5000.0
# 118704              0.0     25000.0
# 130701              0.0     12000.0
# 131151              0.0     65000.0
# ...                 ...         ...
# 957344              0.0     90000.0
# 966697              0.0     65000.0
# 969334              0.0      5000.0
# 991756              0.0      9000.0
# 992369              0.0     35000.0
#
# [145 rows x 2 columns]

# %% [markdown]
# ## Unique values of college enrolment

# %%
df.colenroct14.unique()
# Out:
# array(['1. Not enrolled', '2. 2-year college ', nan,
#        '4. Graduate program', '3. 4-year college'], dtype=object)

# %% [markdown]
# ## Check whether an individual was enrolled in a 4-year college course

# %%
df.filter(like = 'colenr').apply(lambda x:x.str[0:1]=='3').head(4).T
# Out:
# personid     100061  100139  100284  100292
# colenrfeb97   False   False   False   False
# colenroct97   False   False   False   False
# colenrfeb98   False   False   False   False
# colenroct98   False   False   False   False
# colenrfeb99   False   False   False   False
# colenroct99   False   False   False   False
# colenrfeb00   False   False   False   False
# colenroct00   False   False   False    True
# colenrfeb01   False   False   False    True
# colenroct01   False   False   False    True
# colenrfeb02   False   False   False    True
# colenroct02   False   False   False    True
# colenrfeb03   False   False   False    True
# colenroct03   False   False   False    True
# colenrfeb04   False   False   False    True
# colenroct04   False   False   False   False
# colenrfeb05   False   False   False   False
# colenroct05   False   False   False   False
# colenrfeb06   False   False   False   False
# colenroct06   False   False   False   False
# colenrfeb07   False   False   False   False
# colenroct07   False   False   False   False
# colenrfeb08   False   False   False   False
# colenroct08   False   False   False   False
# colenrfeb09   False   False   False   False
# colenroct09   False   False   False   False
# colenrfeb10   False   False   False   False
# colenroct10   False   False   False   False
# colenrfeb11   False   False   False   False
# colenroct11    True   False   False   False
# colenrfeb12    True   False   False   False
# colenroct12    True   False   False   False
# colenrfeb13   False   False   False   False
# colenroct13   False   False   False   False
# colenrfeb14   False   False   False   False
# colenroct14   False   False   False   False
# colenrfeb15   False   False   False   False
# colenroct15   False   False   False   False
# colenrfeb16   False   False   False   False
# colenroct16   False   False   False   False
# colenrfeb17   False   False   False   False
# colenroct17   False   False   False   False

# %%
df.filter(like = 'colenr').apply(lambda x: x.str[0:1] =='3').any(axis =1).head(2)
# Out:
# personid
# 100061     True
# 100139    False
# dtype: bool

# %%
df.colenroct14.unique()
# Out:
# array(['1. Not enrolled', '2. 2-year college ', nan,
#        '4. Graduate program', '3. 4-year college'], dtype=object)

# %% [markdown]
# ## Show individuals with a post-graduate enrolment but no bachelor's enrolment

# %%
no_bachelors = df.loc[df.filter(like = 'colenr').apply(lambda x: x.str[0:1] == '4').\
               any(axis =1) & \
               ~df.filter(like = 'colenr').apply(lambda x: x.str[0:1] == '3').any(axis =1),\
                "colenrfeb97":"colenroct17"]

# %%
len(no_bachelors)
# Out:
# 22

# %%
no_bachelors.head(3).T
# Out:
# personid                  153051               154535               184721
# colenrfeb97                  NaN                  NaN                  NaN
# colenroct97      1. Not enrolled      1. Not enrolled      1. Not enrolled
# colenrfeb98      1. Not enrolled      1. Not enrolled      1. Not enrolled
# colenroct98      1. Not enrolled      1. Not enrolled      1. Not enrolled
# colenrfeb99      1. Not enrolled      1. Not enrolled      1. Not enrolled
# colenroct99      1. Not enrolled      1. Not enrolled      1. Not enrolled
# colenrfeb00      1. Not enrolled      1. Not enrolled      1. Not enrolled
# colenroct00   2. 2-year college       1. Not enrolled      1. Not enrolled
# colenrfeb01      1. Not enrolled      1. Not enrolled      1. Not enrolled
# colenroct01   2. 2-year college       1. Not enrolled      1. Not enrolled
# colenrfeb02   2. 2-year college       1. Not enrolled      1. Not enrolled
# colenroct02   2. 2-year college       1. Not enrolled      1. Not enrolled
# colenrfeb03   2. 2-year college       1. Not enrolled      1. Not enrolled
# colenroct03   2. 2-year college    2. 2-year college       1. Not enrolled
# colenrfeb04      1. Not enrolled   2. 2-year college    2. 2-year college
# colenroct04      1. Not enrolled   2. 2-year college    2. 2-year college
# colenrfeb05   2. 2-year college    2. 2-year college       1. Not enrolled
# colenroct05   2. 2-year college    2. 2-year college       1. Not enrolled
# colenrfeb06   2. 2-year college    2. 2-year college       1. Not enrolled
# colenroct06   2. 2-year college       1. Not enrolled      1. Not enrolled
# colenrfeb07   2. 2-year college       1. Not enrolled   2. 2-year college
# colenroct07      1. Not enrolled      1. Not enrolled   2. 2-year college
# colenrfeb08      1. Not enrolled      1. Not enrolled   2. 2-year college
# colenroct08      1. Not enrolled      1. Not enrolled      1. Not enrolled
# colenrfeb09      1. Not enrolled      1. Not enrolled      1. Not enrolled
# colenroct09      1. Not enrolled      1. Not enrolled      1. Not enrolled
# colenrfeb10      1. Not enrolled      1. Not enrolled      1. Not enrolled
# colenroct10      1. Not enrolled  4. Graduate program  4. Graduate program
# colenrfeb11      1. Not enrolled  4. Graduate program                  NaN
# colenroct11      1. Not enrolled  4. Graduate program                  NaN
# colenrfeb12      1. Not enrolled  4. Graduate program                  NaN
# colenroct12      1. Not enrolled  4. Graduate program                  NaN
# colenrfeb13  4. Graduate program  4. Graduate program                  NaN
# colenroct13      1. Not enrolled  4. Graduate program                  NaN
# colenrfeb14  4. Graduate program  4. Graduate program                  NaN
# colenroct14  4. Graduate program  4. Graduate program                  NaN
# colenrfeb15      1. Not enrolled  4. Graduate program                  NaN
# colenroct15      1. Not enrolled  4. Graduate program                  NaN
# colenrfeb16      1. Not enrolled  4. Graduate program                  NaN
# colenroct16      1. Not enrolled  4. Graduate program                  NaN
# colenrfeb17      1. Not enrolled  4. Graduate program                  NaN
# colenroct17      1. Not enrolled  4. Graduate program                  NaN

# %% [markdown]
# ## Show individuals with bachelor's degree or more but no 4-year college enrollment

# %%
df.highestdegree.value_counts()
# Out:
# highestdegree
# 2. High School     3667
# 4. Bachelors       1673
# 1. GED             1146
# 0. None             953
# 3. Associates       737
# 5. Masters          603
# 7. Professional     120
# 6. PhD               54
# Name: count, dtype: int64

# %%
no_4_year_enrolment = df.loc[df.highestdegree.str[0:1].isin(['4','5','6','7']) & \
                      ~df.filter(like = 'colenr').apply(lambda x: x.str[0:1] =='3').any(axis=1), \
                      "colenrfeb97":"colenroct17"]

# %%
len(no_4_year_enrolment)
# Out:
# 39

# %%
no_4_year_enrolment.head(2).T
# Out:
# personid                 113486              118749
# colenrfeb97     1. Not enrolled                 NaN
# colenroct97     1. Not enrolled     1. Not enrolled
# colenrfeb98     1. Not enrolled     1. Not enrolled
# colenroct98     1. Not enrolled     1. Not enrolled
# colenrfeb99     1. Not enrolled     1. Not enrolled
# colenroct99     1. Not enrolled     1. Not enrolled
# colenrfeb00     1. Not enrolled     1. Not enrolled
# colenroct00     1. Not enrolled     1. Not enrolled
# colenrfeb01     1. Not enrolled     1. Not enrolled
# colenroct01  2. 2-year college      1. Not enrolled
# colenrfeb02  2. 2-year college      1. Not enrolled
# colenroct02  2. 2-year college      1. Not enrolled
# colenrfeb03  2. 2-year college      1. Not enrolled
# colenroct03  2. 2-year college      1. Not enrolled
# colenrfeb04  2. 2-year college      1. Not enrolled
# colenroct04     1. Not enrolled     1. Not enrolled
# colenrfeb05     1. Not enrolled     1. Not enrolled
# colenroct05     1. Not enrolled     1. Not enrolled
# colenrfeb06     1. Not enrolled     1. Not enrolled
# colenroct06     1. Not enrolled     1. Not enrolled
# colenrfeb07     1. Not enrolled  2. 2-year college
# colenroct07     1. Not enrolled  2. 2-year college
# colenrfeb08     1. Not enrolled     1. Not enrolled
# colenroct08     1. Not enrolled     1. Not enrolled
# colenrfeb09     1. Not enrolled     1. Not enrolled
# colenroct09     1. Not enrolled     1. Not enrolled
# colenrfeb10     1. Not enrolled     1. Not enrolled
# colenroct10     1. Not enrolled     1. Not enrolled
# colenrfeb11     1. Not enrolled     1. Not enrolled
# colenroct11     1. Not enrolled     1. Not enrolled
# colenrfeb12     1. Not enrolled     1. Not enrolled
# colenroct12     1. Not enrolled     1. Not enrolled
# colenrfeb13     1. Not enrolled     1. Not enrolled
# colenroct13     1. Not enrolled     1. Not enrolled
# colenrfeb14     1. Not enrolled     1. Not enrolled
# colenroct14     1. Not enrolled     1. Not enrolled
# colenrfeb15     1. Not enrolled     1. Not enrolled
# colenroct15     1. Not enrolled     1. Not enrolled
# colenrfeb16                 NaN     1. Not enrolled
# colenroct16                 NaN     1. Not enrolled
# colenrfeb17                 NaN     1. Not enrolled
# colenroct17                 NaN     1. Not enrolled

# %% [markdown]
# ## Show individuals with high wage income

# %%
highwages = df.loc[df.wageincome > df.wageincome.mean() +(df.wageincome.std() *3), ['wageincome']]

# %%
highwages.head(3)
# Out:
#           wageincome
# personid
# 131858      235884.0
# 133619      235884.0
# 151863      235884.0

# %% [markdown]
# ## Show individuals with large changes in weeks worked for the most recent year

# %%
workchanges = df.loc[~df.loc[:,"weeksworked12":"weeksworked16"].mean(axis =1).between(df.weeksworked17 * 0.5, df.weeksworked17*2)\
            & ~df.weeksworked17.isnull(),"weeksworked12":"weeksworked17"]

# %% [raw]
# axis = 1 is used to calculate mean across the "weeksworked" columns
# rather than for each individual(by using axis=0).
#
#
# We are seeing if the weeks worked is less than 50 % of the mean between 2012 and 2016
# or if it is more than double of the mean during that period
#
# We are also getting rid of null values in the final data

# %%
len(workchanges)
# Out:
# 1160

# %%
workchanges.sample(3).T
# Out:
# personid       787304  765486  129197
# weeksworked12    52.0    21.0    48.0
# weeksworked13    45.0    19.0     0.0
# weeksworked14    52.0    52.0     0.0
# weeksworked15    52.0    33.0    13.0
# weeksworked16    53.0     0.0    53.0
# weeksworked17     9.0     0.0    52.0

# %% [markdown]
# ## Show inconsistencies in the highest grade completed and highest degree

# %% [raw]
# Use the crosstab function to show the "highestgradecompleted" by "highestdegree" for people
# with the "highestgradecompleted" less than 12.

# %%
df.highestgradecompleted.value_counts()
# Out:
# highestgradecompleted
# 12.0    1389
# 16.0    1016
# 14.0     750
# 13.0     538
# 18.0     407
# 15.0     397
# 17.0     388
# 11.0     364
# 20.0     333
# 10.0     329
# 9.0      292
# 19.0     203
# 8.0      198
# 7.0       31
# 6.0       16
# 95.0      11
# 5.0        1
# Name: count, dtype: int64

# %%
df.highestdegree.value_counts()
# Out:
# highestdegree
# 2. High School     3667
# 4. Bachelors       1673
# 1. GED             1146
# 0. None             953
# 3. Associates       737
# 5. Masters          603
# 7. Professional     120
# 6. PhD               54
# Name: count, dtype: int64

# %%
less_than_12 = df.loc[df.highestgradecompleted <12, ["highestgradecompleted", "highestdegree"]]

# %% [markdown]
# ## Using crosstab function to create a frequency table

# %%
pd.crosstab(less_than_12.highestgradecompleted, less_than_12.highestdegree)
# Out:
# highestdegree          0. None  1. GED  2. High School
# highestgradecompleted
# 5.0                          0       0               1
# 6.0                         11       5               0
# 7.0                         24       6               1
# 8.0                        113      78               7
# 9.0                        112     169               8
# 10.0                       111     204              13
# 11.0                       120     200              41

# %% [raw]
# In the above, there are some people who said thta their "highest grade completed" is "11th"
#
# but indicated that their "highest degree" is "high school"
